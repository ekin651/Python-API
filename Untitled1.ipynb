# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_key import weather_api_key


#Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 622

# %%
### Perform API Calls

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
params={"key":weather_api_key}

# Build partial query URL
query = f"{url}appid={weather_api_key}&units={units}&q="+ city

query
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=bdda03c2e5c176b252f5fab19ca47a22&units=metric&q=khatanga'

# %%
# Get weather data
print("Beginning Data Retrival")
print("------------------------------")
set_count = 1
record_count = 1
weather_data = {"City":[],"Cloudiness":[],"Country":[],"Date":[],"Humidity":[],"Lat":[],"Lng":[],"Max Temp":[],"Wind Speed": []}
for city in cities:
    weather_response = requests.get(query)
    weather_response_json = weather_response.json()
    
    if weather_response.status_code == 200:
        weather_data["City"].append(city)
        weather_data["Cloudiness"].append(weather_response_json["clouds"]['all'])
        weather_data["Country"].append(weather_response_json['sys']['country'])
        weather_data["Date"].append(weather_response_json['dt'])
        weather_data["Humidity"].append(weather_response_json['main']['humidity'])
        weather_data["Lat"].append(weather_response_json['coord']['lat'])
        weather_data["Lng"].append(weather_response_json['coord']['lon'])
        weather_data["Max Temp"].append(weather_response_json['main']['temp_max'])
        weather_data["Wind Speed"].append(weather_response_json['wind']['speed'])
        if record_count <= 50:
            print(f"Processing Record {record_count} of Set {set_count} | {city}")
            record_count += 1 
        else:
            record_count = 0
            set_count += 1
            print(f"Processing Record {record_count} of Set {set_count} | {city}")
            record_count += 1
    else:
        print("City not found. Skipping...")
print("-------------------------")
print("Data Retrieval Complete")
print("-------------------------")
# Out:
# Beginning Data Retrival
# ------------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | garowe
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | vaitupu
# Processing Record 5 of Set 1 | lagoa
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | barentsburg
# Processing Record 8 of Set 1 | soyo
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | muzhi
# Processing Record 11 of Set 1 | tuatapere
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | eureka
# Processing Record 14 of Set 1 | nuuk
# Processing Record 15 of Set 1 | lae
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | marolambo
# Processing Record 18 of Set 1 | eskasem
# Processing Record 19 of Set 1 | souillac
# Processing Record 20 of Set 1 | saint george
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | qaqortoq
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | georgetown
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | samusu
# Processing Record 27 of Set 1 | ponta do sol
# Processing Record 28 of Set 1 | maceio
# Processing Record 29 of Set 1 | pavlovskiy posad
# Processing Record 30 of Set 1 | general roca
# Processing Record 31 of Set 1 | nieuw amsterdam
# Processing Record 32 of Set 1 | derzhavinsk
# Processing Record 33 of Set 1 | teya
# Processing Record 34 of Set 1 | tiksi
# Processing Record 35 of Set 1 | svetlogorsk
# Processing Record 36 of Set 1 | puno
# Processing Record 37 of Set 1 | saskylakh
# Processing Record 38 of Set 1 | watertown
# Processing Record 39 of Set 1 | vila franca do campo
# Processing Record 40 of Set 1 | ancona
# Processing Record 41 of Set 1 | hithadhoo
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | iqaluit
# Processing Record 44 of Set 1 | qaanaaq
# Processing Record 45 of Set 1 | puerto ayora
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | cabo san lucas
# Processing Record 48 of Set 1 | rochegda
# Processing Record 49 of Set 1 | chuy
# Processing Record 50 of Set 1 | gewane
# Processing Record 0 of Set 2 | sisimiut
# Processing Record 1 of Set 2 | bonavista
# Processing Record 2 of Set 2 | maroua
# Processing Record 3 of Set 2 | troitsko-pechorsk
# Processing Record 4 of Set 2 | kadykchan
# Processing Record 5 of Set 2 | kimbe
# Processing Record 6 of Set 2 | roatan
# Processing Record 7 of Set 2 | agadez
# Processing Record 8 of Set 2 | malanje
# Processing Record 9 of Set 2 | narsaq
# Processing Record 10 of Set 2 | shimoda
# Processing Record 11 of Set 2 | la ronge
# Processing Record 12 of Set 2 | cidreira
# Processing Record 13 of Set 2 | celestun
# Processing Record 14 of Set 2 | khandyga
# Processing Record 15 of Set 2 | biri
# Processing Record 16 of Set 2 | chumikan
# Processing Record 17 of Set 2 | pisco
# Processing Record 18 of Set 2 | necochea
# Processing Record 19 of Set 2 | cape town
# Processing Record 20 of Set 2 
# Processing Record 6 of Set 4 | tuktoyaktuk
# Processing Record 7 of Set 4 | batagay
# Processing Record 8 of Set 4 | port moresby
# Processing Record 9 of Set 4 | bafilo
# Processing Record 10 of Set 4 | haibowan
# Processing Record 11 of Set 4 | margate
# Processing Record 12 of Set 4 | torbay
# Processing Record 13 of Set 4 | licata
# Processing Record 14 of Set 4 | trairi
# Processing Record 15 of Set 4 | markivka
# Processing Record 16 of Set 4 | lima
# Processing Record 17 of Set 4 | novoagansk
# Processing Record 18 of Set 4 | samarai
# Processing Record 19 of Set 4 | dunedin
# Processing Record 20 of Set 4 | semirom
# Processing Record 21 of Set 4 | port elizabeth
# Processing Record 22 of Set 4 | kodiak
# Processing Record 23 of Set 4 | dryden
# Processing Record 24 of Set 4 | verkhnevilyuysk
# Processing Record 25 of Set 4 | dimitrovgrad
# Processing Record 26 of Set 4 | zarubino
# Processing Record 27 of Set 4 | mayor pablo lagerenza
# Processing Record 28 of Set 4 | anadyr
# Processing Record 29 of Set 4 | abu dhabi
# Processing Record 30 of Set 4 | thinadhoo
# Processing Record 31 of Set 4 | ukiah
# Processing Record 32 of Set 4 | rio gallegos
# Processing Record 33 of Set 4 | karwar
# Processing Record 34 of Set 4 | pio ix
# Processing Record 35 of Set 4 | kamenskoye
# Processing Record 36 of Set 4 | avarua
# Processing Record 37 of Set 4 | hilo
# Processing Record 38 of Set 4 | tefe
# Processing Record 39 of Set 4 | biak
# Processing Record 40 of Set 4 | swift current
# Processing Record 41 of Set 4 | abu samrah
# Processing Record 42 of Set 4 | avera
# Processing Record 43 of Set 4 | salalah
# Processing Record 44 of Set 4 | carutapera
# Processing Record 45 of Set 4 | katsuura
# Processing Record 46 of Set 4 | ust-kamchatsk
# Processing Record 47 of Set 4 | amderma
# Processing Record 48 of Set 4 | carnarvon
# Processing Record 49 of Set 4 | vanavara
# Processing Record 50 of Set 4 | harper
# Processing Record 0 of Set 5 | vestmannaeyjar
# Processing Record 1 of Set 5 | tasiilaq
# Processing Record 2 of Set 5 | kaitangata
# Processing Record 3 of Set 5 | joshimath
# Processing Record 4 of Set 5 | zhangjiakou
# Processing Record 5 of Set 5 | kaka
# Processing Record 6 of Set 5 | qui nhon
# Processing Record 7 of Set 5 | langnau
# Processing Record 8 of Set 5 | srednekolymsk
# Processing Record 9 of Set 5 | port hedland
# Processing Record 10 of Set 5 | yichang
# Processing Record 11 of Set 5 | santa cruz de tenerife
# Processing Record 12 of Set 5 | marzuq
# Processing Record 13 of Set 5 | kalga
# Processing Record 14 of Set 5 | sitka
# Processing Record 15 of Set 5 | bambous virieux
# Processing Record 16 of Set 5 | saldanha
# Processing Record 17 of Set 5 | flin flon
# Processing Record 18 of Set 5 | caravelas
# Processing Record 19 of Set 5 | ares
# Processing Record 20 of Set 5 | shubarkuduk
# Processing Record 21 of Set 5 | san policarpo
# Processing Record 22 of Set 5 | bairiki
# Processing Record 23 of Set 5 | yakima
# Processing Record 24 of Set 5 | fortuna
# Processing Record 25 of Set 5 | dien bien
# Processing Record 26 of Set 5 | talcahuano
# Processing Record 27 of Set 5 | san cristobal
# Processing Record 28 of Set 5 | college
# Processing Record 29 of Set 5 | luganville
# Processing Record 30 of Set 5 | antofagasta
# Processing Record 31 of Set 5 | luderitz
# Processing Record 32 of Set 5 | naze
# Processing Record 33 of Set 5 | urucui
# Processing Record 34 of Set 5 | wellington
# Processing Record 35 of Set 5 | grindavik
# Processing Record 36 of Set 5 | hamilton
# Processing Record 37 of Set 5 | louisbourg
# Processing Record 38 of Set 5 | fonte boa
# Processing Record 39 of Set 5 | fort-shevchenko
# Processing Record 40 of Set 5 | fruitvale
# Processing Record 41 of Set 5 | aswan
# Processing Record 42 of Set 5 | jasper
# Processing Record 43 of Set 5 | valparaiso
# Processing Record 44 of Set 5 | richards bay
# Processing Record 45 of Set 5 | atar
# Processing Record 46 of Set 5 | hermanus
# Processing Record 47 of Set 5 | pitimbu
# Processing Record 48 of Set 5 | meulaboh
# Processing Record 49 of Set 5 | attawapiskat
# Processing Record 50 of Set 5 | tambacounda
# Processing Record 0 of Set 6 | macia
# Processing Record 1 of Set 6 | asau
# Processing Record 2 of Set 6 | hobyo
# Processing Record 3 of Set 6 | marystown
# Processing Record 4 of Set 6 | berlevag
# Processing Record 5 of Set 6 | haines junction
# Processing Record 6 of Set 6 | lukhovitsy
# Processing Record 7 of Set 6 | saint-augustin
# Processing Record 8 of Set 6 | ambulu
# Processing Record 9 of Set 6 | ostrovnoy
# Processing Record 10 of Set 6 | mezen
# Processing Record 11 of Set 6 | sisophon
# Processing Record 12 of Set 6 | vanimo
# Processing Record 13 of Set 6 | artyk
# Processing Record 14 of Set 6 | khatanga
# Processing Record 15 of Set 6 | zaysan
# Processing Record 16 of Set 6 | qixingtai
# Processing Record 17 of Set 6 | marsh harbour
# Processing Record 18 of Set 6 | basugaon
# Processing Record 19 of Set 6 | banda aceh
# Processing Record 20 of Set 6 | imbituba
# Processing Record 21 of Set 6 | cherskiy
# Processing Record 22 of Set 6 | bubaque
# Processing Record 23 of Set 6 | elko
# Processing Record 24 of Set 6 | namatanai
# Processing Record 25 of Set 6 | half moon bay
# Processing Record 26 of Set 6 | san pedro
# Processing Record 27 of Set 6 | kununurra
# Processing Record 28 of Set 6 | hailey
# Processing Record 29 of Set 6 | kamenka
# Processing Record 30 of Set 6 | yarmolyntsi
# Processing Record 31 of Set 6 | hasaki
# Processing Record 32 of Set 6 | isangel
# Processing Record 33 of Set 6 | plover
# Processing Record 34 of Set 6 | odweyne
# Processing Record 35 of Set 6 | port-gentil
# Processing Record 36 of Set 6 | shelui
# Processing Record 37 of Set 6 | kavaratti
# Processing Record 38 of Set 6 | te anau
# Processing Record 39 of Set 6 | ko samui
# Processing Record 40 of Set 6 | okakarara
# Processing Record 41 of Set 6 | buin
# Processing Record 42 of Set 6 | azimur
# Processing Record 43 of Set 6 | jala
# Processing Record 44 of Set 6 | zemetchino
# Processing Record 45 of Set 6 | jumla
# Processing Record 46 of Set 6 | saint-pierre
# Processing Record 47 of Set 6 | sao pedro do sul
# Processing Record 48 of Set 6 | san patricio
# Processing Record 49 of Set 6 | cap malheureux
# Processing Record 50 of Set 6 | kidal
# Processing Record 0 of Set 7 | totness
# Processing Record 1 of Set 7 | hopkinsville
# Processing Record 2 of Set 7 | hervey bay
# Processing Record 43 of Set 9 | daru
# Processing Record 44 of Set 9 | kangaatsiaq
# Processing Record 45 of Set 9 | langarud
# Processing Record 46 of Set 9 | denpasar
# Processing Record 47 of Set 9 | clyde river
# Processing Record 48 of Set 9 | padang
# Processing Record 49 of Set 9 | fresnillo
# Processing Record 50 of Set 9 | sobolevo
# Processing Record 0 of Set 10 | chimbote
# Processing Record 1 of Set 10 | paita
# Processing Record 2 of Set 10 | mrirt
# Processing Record 3 of Set 10 | hihifo
# Processing Record 4 of Set 10 | hashtrud
# Processing Record 5 of Set 10 | praia da vitoria
# Processing Record 6 of Set 10 | smithers
# Processing Record 7 of Set 10 | hofn
# Processing Record 8 of Set 10 | totma
# Processing Record 9 of Set 10 | haileybury
# Processing Record 10 of Set 10 | zhanatas
# Processing Record 11 of Set 10 | billings
# Processing Record 12 of Set 10 | bursa
# Processing Record 13 of Set 10 | maniitsoq
# Processing Record 14 of Set 10 | bathsheba
# Processing Record 15 of Set 10 | kawalu
# Processing Record 16 of Set 10 | mecca
# Processing Record 17 of Set 10 | lazaro cardenas
# Processing Record 18 of Set 10 | lac du bonnet
# Processing Record 19 of Set 10 | mumford
# Processing Record 20 of Set 10 | turan
# Processing Record 21 of Set 10 | ejido
# Processing Record 22 of Set 10 | manuk mangkaw
# Processing Record 23 of Set 10 | rundu
# Processing Record 24 of Set 10 | meadow lake
# Processing Record 25 of Set 10 | alice springs
# Processing Record 26 of Set 10 | aykhal
# Processing Record 27 of Set 10 | kloulklubed
# Processing Record 28 of Set 10 | hurghada
# Processing Record 29 of Set 10 | jiwani
# Processing Record 30 of Set 10 | formosa do rio preto
# Processing Record 31 of Set 10 | ugep
# Processing Record 32 of Set 10 | urdoma
# Processing Record 33 of Set 10 | thabazimbi
# Processing Record 34 of Set 10 | mareeba
# Processing Record 35 of Set 10 | hegang
# Processing Record 36 of Set 10 | balaipungut
# Processing Record 37 of Set 10 | mulanje
# Processing Record 38 of Set 10 | semnan
# Processing Record 39 of Set 10 | coahuayana
# Processing Record 40 of Set 10 | beyneu
# Processing Record 41 of Set 10 | yefira
# Processing Record 42 of Set 10 | ankara
# Processing Record 43 of Set 10 | pouebo
# Processing Record 44 of Set 10 | indian head
# Processing Record 45 of Set 10 | skelleftea
# Processing Record 46 of Set 10 | kargasok
# Processing Record 47 of Set 10 | sao joao da barra
# Processing Record 48 of Set 10 | vagur
# Processing Record 49 of Set 10 | mut
# Processing Record 50 of Set 10 | yelizavetino
# Processing Record 0 of Set 11 | viedma
# Processing Record 1 of Set 11 | amapa
# Processing Record 2 of Set 11 | yuancheng
# Processing Record 3 of Set 11 | reggio di calabria
# Processing Record 4 of Set 11 | tommot
# Processing Record 5 of Set 11 | black river
# Processing Record 6 of Set 11 | codajas
# Processing Record 7 of Set 11 | waw
# Processing Record 8 of Set 11 | enid
# Processing Record 9 of Set 11 | corinto
# Processing Record 10 of Set 11 | wanning
# Processing Record 11 of Set 11 | loiza
# Processing Record 12 of Set 11 | guadix
# Processing Record 13 of Set 11 | nakhon si thammarat
# Processing Record 14 of Set 11 | pauini
# Processing Record 15 of Set 11 | san-pedro
# Processing Record 16 of Set 11 | marion
# Processing Record 17 of Set 11 | yenagoa
# Processing Record 18 of Set 11 | logrono
# Processing Record 19 of Set 11 | murmashi
# Processing Record 20 of Set 11 | maloshuyka
# Processing Record 21 of Set 11 | yuli
# Processing Record 22 of Set 11 | santa cruz
# Processing Record 23 of Set 11 | xanxere
# Processing Record 24 of Set 11 | sao filipe
# Processing Record 25 of Set 11 | saveh
# Processing Record 26 of Set 11 | farafangana
# Processing Record 27 of Set 11 | puksoozero
# Processing Record 28 of Set 11 | pushkar
# Processing Record 29 of Set 11 | baykit
# Processing Record 30 of Set 11 | roanoke
# Processing Record 31 of Set 11 | killybegs
# Processing Record 32 of Set 11 | loksa
# Processing Record 33 of Set 11 | sheridan
# Processing Record 34 of Set 11 | vung tau
# Processing Record 35 of Set 11 | carmen
# Processing Record 36 of Set 11 | grand river south east
# Processing Record 37 of Set 11 | yerbogachen
# Processing Record 38 of Set 11 | emilio carranza
# Processing Record 39 of Set 11 | pirmasens
# Processing Record 40 of Set 11 | pacifica
# Processing Record 41 of Set 11 | salinas
# Processing Record 42 of Set 11 | shahr-e babak
# Processing Record 43 of Set 11 | hirara
# Processing Record 44 of Set 11 | lloydminster
# Processing Record 45 of Set 11 | grand gaube
# Processing Record 46 of Set 11 | bayanday
# Processing Record 47 of Set 11 | ulundi
# Processing Record 48 of Set 11 | kaeo
# Processing Record 49 of Set 11 | nizhneyansk
# Processing Record 50 of Set 11 | ahipara
# Processing Record 0 of Set 12 | fort myers beach
# Processing Record 1 of Set 12 | barghis
# Processing Record 2 of Set 12 | tessalit
# Processing Record 3 of Set 12 | nara
# Processing Record 4 of Set 12 | naranjal
# Processing Record 5 of Set 12 | siilinjarvi
# Processing Record 6 of Set 12 | bongandanga
# Processing Record 7 of Set 12 | cartagena
# Processing Record 8 of Set 12 | myrtle beach
# Processing Record 9 of Set 12 | panguna
# Processing Record 10 of Set 12 | palabuhanratu
# Processing Record 11 of Set 12 | dungarvan
# Processing Record 12 of Set 12 | barcelos
# Processing Record 13 of Set 12 | zhangye
# Processing Record 14 of Set 12 | yabelo
# Processing Record 15 of Set 12 | noumea
# Processing Record 16 of Set 12 | chicama
# Processing Record 17 of Set 12 | tabou
# Processing Record 18 of Set 12 | prachuap khiri khan
# Processing Record 19 of Set 12 | shahe
# Processing Record 20 of Set 12 | mikhaylovka
# Processing Record 21 of Set 12 | vostok
# Processing Record 22 of Set 12 | manzanillo
# Processing Record 23 of Set 12 | cockburn town
# Processing Record 24 of Set 12 | adrar
# Processing Record 25 of Set 12 | nome
# Processing Record 26 of Set 12 | aleksandrovskiy zavod
# Processing Record 27 of Set 12 | dolores
# Processing Record 28 of Set 12 | cranbrook
# Processing Record 29 of Set 12 | luangwa
# Processing Record 30 of Set 12 | coihueco
# Processing Record 31 of Set 12 | lingao
# Processing Record 32 of Set 12 | hokitika
# Processing Record 33 of Set 12 | bababe
# Processing Record 34 of Set 12 | pierre
# Processing Record 35 of Set 12 | eldorado
# Processing Record 36 of Set 12 | leningradskiy
# Processing Record 37 of Set 12 | san quintin
# Processing Record 38 of Set 12 | hualmay
# Processing Record 39 of Set 12 | fevralsk
# Processing Record 40 of Set 12 | qinhuangdao
# Processing Record 41 of Set 12 | pevek
# Processing Record 42 of Set 12 | lugovskiy
# Processing Record 43 of Set 12 | santa cruz del sur
# Processing Record 44 of Set 12 | shu
# Processing Record 45 of Set 12 | opuwo
# Processing Record 46 of Set 12 | flinders
# Processing Record 47 of Set 12 | denizli
# Processing Record 48 of Set 12 | birao
# Processing Record 49 of Set 12 | karamea
# Processing Record 50 of Set 12 | komsomolskiy
# Processing Record 0 of Set 13 | victoria
# Processing Record 1 of Set 13 | salaga
# Processing Record 2 of Set 13 | torquay
# Processing Record 3 of Set 13 | sinnamary
# Processing Record 4 of Set 13 | christchurch
# Processing Record 5 of Set 13 | popondetta
# Processing Record 6 of Set 13 | tura
# Processing Record 7 of Set 13 | quelimane
# Processing Record 8 of Set 13 | grand island
# Processing Record 9 of Set 13 | dharchula
# Processing Record 10 of Set 13 | pouembout
# -------------------------
# Data Retrieval Complete
# -------------------------

# %%
# output data to csv
weather_df.to_csv(output_data_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-85e9e8f609f5> in <module>
#       1 # output data to csv
# ----> 2 weather_df.to_csv(output_data_file)
#
# NameError: name 'weather_df' is not defined

# %%
weather_df = pd.DataFrame(weather_data)
weather_df.count()
# Out:
# City          594
# Cloudiness    594
# Country       594
# Date          594
# Humidity      594
# Lat           594
# Lng           594
# Max Temp      594
# Wind Speed    594
# dtype: int64

# %%
weather_response_dict={
    "City":city,                             
    "Country":Country,
    "Date":Dates,
    "Humidity": Humidity,
    "Lat": Lat,
    "Lng": Lng,
    "Max Temp":max_temps,
    "Wind Speed": wind_speed
}   
  


weather_response = pd.DataFrame(weather_response_dict)
weather_city.to_csv("cities.csv", encoding="utf-8", index=False)

weather_response.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9f1598800acb> in <module>
#       1 weather_response_dict={
# ----> 2     "City":city,
#       3     "Country":Country,
#       4     "Date":Dates,
#       5     "Humidity": Humidity,
#
# NameError: name 'city' is not defined

# %%
weather_df.to_csv("cities.csv", encoding="utf-8", index=False)

# %%
# Build a scatter plot for each data type
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature" + " " + date_stamp)
plt.ylabel("Max Temperature F")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("City Latitude vs. Max Temperature.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-05615ff3b51d> in <module>
#       1 # Build a scatter plot for each data type
# ----> 2 plt.scatter(weather["Lat"], weather["Max Temp"], marker="o")
#       3
#       4 # Incorporate the other graph properties
#       5 plt.title("City Latitude vs. Max Temperature" + " " + date_stamp)
#
# NameError: name 'weather' is not defined

# %%
# Latitude vs Humidity
x_values=weather_df['Lat']
y_values=weather_df['Humidity']
plt.scatter(x_values,y_values)

# Add chart labels
plt.title("City Latitude vs Humidity")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim(-90,90)

# Save the figure
plt.savefig("Lat_vs_Humidity.png")

# Show plot
plt.show()
